# %% [markdown]
# # 03 - Pré-processamento
#
# Limpeza, tratamento de nulos, normalização e preparação das features para clustering.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from pathlib import Path

DATA_DIR = Path('../data')
OUTPUT_DIR = Path('../outputs')

# %%
# Carregar dados
cnefe = pd.read_parquet(DATA_DIR / 'cnefe_2010')
scraping = pd.read_parquet(DATA_DIR / 'web_scraping_pre_processado')

# %%
# Tratamento de nulos, seleção de features e normalização
